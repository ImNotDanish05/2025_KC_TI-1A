# %% [markdown]
# <a href="https://colab.research.google.com/github/ImNotDanish05/2025_KC_TI-1A/blob/main/P5_PENGOLAHAN_DATA_MENGGUNAKAN_PANDAS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***1.	Membaca berbagai format file menggunakan Pandas***
# # **a.	Membaca file CSV**

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')

dir = "/content/drive/MyDrive/Danish05/File Belajar/Coding Fun/Testing Pandaa/"
df = pd.read_csv(dir + "data.csv")
print(df.to_string())
# Out:
# Mounted at /content/drive
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# ...

# %%
print(f"{df}\n")
print(pd.options.display.max_rows)
pd.options.display.max_rows = 9999
df = pd.read_csv(dir + "data.csv")
print(f"{df}\n")
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %% [markdown]
# # **b.	Membaca file JSON**

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')

dir = "/content/drive/MyDrive/Danish05/File Belajar/Coding Fun/Testing Pandaa/"
df = pd.read_json(dir + 'data.json')
print(df.to_string())
# Out:
# Mounted at /content/drive
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.5
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# ...

# %% [markdown]
# # **c.	Menggunakan Parameter pada Pandas Read**

# %%
df = pd.read_csv(dir + 'data.csv', sep=',', header=0)
print(df)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %% [markdown]
# # **d.	Membaca Custom Data**

# %%
data = {
    "Durasi":{
        "0": 60,
        "1": 50,
        "2": 35,
        "3": 789
    },
    "Detak":{
        "0":110,
        "1":117,
        "2":103,
        "3":109
    },
    "Maks Detak":{
        "0": 130,
        "1": 145,
        "2": 135,
        "3": 175
    },
    "Kalori":{
        "0":409,
        "1":479,
        "2":340,
        "3":282
    }
}
df = pd.DataFrame(data)
print(df)
# Out:
#    Durasi  Detak  Maks Detak  Kalori
# 0      60    110         130     409
# 1      50    117         145     479
# 2      35    103         135     340
# 3     789    109         175     282

# %% [markdown]
# # ***2.	Membuat dan Mengakses Elemen Series***
# # **a.	Membuat Series dari sebuah List Python**

# %%
import pandas as pd

li = [1, 7, 2]
se = pd.Series(li)

print(se)
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %% [markdown]
# # **b.	Mengakses Elemen pada Series**

# %%
li = [1, 7, 2]
se = pd.Series(li)

print(se[0])
# Out:
# 1

# %% [markdown]
# # **c.	Memberi Label pada Series**

# %%
li = [1, 7, 2]
se = pd.Series(li, index=["x", "y", "z"])

print(se['x'])
# Out:
# 1

# %%
calories = {
    "day1": 420,
    "day2": 380,
    "day3": 390
}
se = pd.Series(calories)
print(se)

print(" ")

calories = { "day1": 420, "day2": 380, "day3": 390 }
se = pd.Series(calories)
print(se)
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64
#
# day1    420
# day2    380
# day3    390
# dtype: int64

# %% [markdown]
# # ***3.	Membuat DataFrame***
# # **a.	Membuat DataFrame**

# %%
import pandas as pd
df = pd.DataFrame(data ={
    "Nama": ["John", "Jane", "Doe"],
    "Umur": [25, 30, 35],
    "Kota": ["Jakarta", "Bandung", "Surabaya"]
})
print(f"{df}\n")
print(f"{df.columns}\n")
print(f"{df.columns.values[0]}\n")
# Out:
#    Nama  Umur      Kota
# 0  John    25   Jakarta
# 1  Jane    30   Bandung
# 2   Doe    35  Surabaya
#
# Index(['Nama', 'Umur', 'Kota'], dtype='object')
#
# Nama

# %%
data = {
    "kalori": [420, 380, 390],
    "durasi": [50, 40, 45]
}

df = pd.DataFrame(data)
df
# Out:
#    kalori  durasi
# 0     420      50
# 1     380      40
# 2     390      45
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df['kalori'].plot(kind='hist', bins=20, title='kalori')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df['durasi'].plot(kind='hist', bins=20, title='durasi')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df.plot(kind='scatter', x='kalori', y='durasi', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# ...

# %% [markdown]
# # **b.	Mengakses Elemen pada DataFrame**
# df.iloc[baris:kolom]

# %%
df.iloc[0:2, [0,1]]
# Out:
#    kalori  durasi
# 0     420      50
# 1     380      40

# %%
df.iloc[0:2, 0:2]
# Out:
#    kalori  durasi
# 0     420      50
# 1     380      40

# %%
df.iloc[:, 0:2]
# Out:
#    kalori  durasi
# 0     420      50
# 1     380      40
# 2     390      45

# %%
df.loc[0:2, :'kalori']
# Out:
#    kalori
# 0     420
# 1     380
# 2     390

# %%
df.loc[0:2, ['kalori', 'durasi']]
# Out:
#    kalori  durasi
# 0     420      50
# 1     380      40
# 2     390      45

# %%
df['kalori'][0]
# Out:
# np.int64(420)

# %%
df[['kalori']]
# Out:
#    kalori
# 0     420
# 1     380
# 2     390

# %%
df[[
    'kalori'
]].loc[[0,1]]
# Out:
#    kalori
# 0     420
# 1     380

# %% [markdown]
# # **c.	Memberi Nama pada Index**

# %%
data = {
    "kalori": [420, 380, 390],
    "durasi": [50, 40, 45]
}

df = pd.DataFrame(data, index=["hari1", "hari2", "hari3"])
print(df)
df
# Out:
#        kalori  durasi
# hari1     420      50
# hari2     380      40
# hari3     390      45
#        kalori  durasi
# hari1     420      50
# hari2     380      40
# hari3     390      45

# %% [markdown]
# # **d.	Melihat DataFrame**

# %%
df = pd.read_csv(dir + 'data.csv')
print(df)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
df.head()
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
df.tail()
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4

# %%
df.head(10)
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0
# 5        60    102       127     300.0
# 6        60    110       136     374.0
# 7        45    104       134     253.3
# 8        30    109       133     195.1
# 9        60     98       124     269.0

# %%
df.shape
# Out:
# (169, 4)

# %%
df.dtypes
# Out:
# Duration      int64
# Pulse         int64
# Maxpulse      int64
# Calories    float64
# dtype: object

# %% [markdown]
# # **e.	Membaca Informasi pada DataFrame**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB

# %%
df.describe()
# Out:
#          Duration       Pulse    Maxpulse     Calories
# count  169.000000  169.000000  169.000000   164.000000
# mean    63.846154  107.461538  134.047337   375.790244
# std     42.299949   14.510259   16.450434   266.379919
# min     15.000000   80.000000  100.000000    50.300000
# 25%     45.000000  100.000000  124.000000   250.925000
# 50%     60.000000  105.000000  131.000000   318.600000
# 75%     60.000000  111.000000  141.000000   387.600000
# max    300.000000  159.000000  184.000000  1860.400000

# %%
data = {
    "kalori": [420, 380, 390],
    "durasi": [50, 40, 45]
}
df = pd.DataFrame(data, index=["hari1", "hari2", "hari3"])
df['kalori'].mean(), df['kalori'].median(), df['kalori'].mode()[0]
# Out:
# (np.float64(396.6666666666667), 390.0, np.int64(380))

# %%
df.corr()
# Out:
#           kalori    durasi
# kalori  1.000000  0.960769
# durasi  0.960769  1.000000
